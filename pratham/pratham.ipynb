# %%
import pandas as pd
import matplotlib as plt

# %%
bridges = pd.read_csv("../assets/bridges.csv", sep=",", header=0)
speed_humps = pd.read_csv("../assets/speed_humps.csv", sep=",", header=0)
print(speed_humps)

# %%
res = speed_humps.groupby('neighborhood')['_id'].sum().sort_values(ascending=True)
# Create a bar plot
ax = res.plot(kind='line', title="Speed Bumps by Neighborhood", xlabel="", ylabel="Bumps")
# Get the x-axis tick labels
x_labels = res.index

ax.set_xticks(range(len(x_labels)))
ax.set_xticklabels(x_labels, rotation=90)
# Out:
# [Text(0, 0, 'Central Oakland'),
#  Text(1, 0, 'Bloomfield'),
#  Text(2, 0, 'Stanton Heights'),
#  Text(3, 0, 'Overbrook'),
#  Text(4, 0, 'Brookline'),
#  Text(5, 0, 'Highland Park'),
#  Text(6, 0, 'Mount Washington'),
#  Text(7, 0, 'South Side Flats'),
#  Text(8, 0, 'Homewood South'),
#  Text(9, 0, 'Squirrel Hill North'),
#  Text(10, 0, 'Polish Hill'),
#  Text(11, 0, 'North Oakland'),
#  Text(12, 0, 'Upper Hill'),
#  Text(13, 0, 'Garfield'),
#  Text(14, 0, 'Perry North'),
#  Text(15, 0, 'South Side Slopes'),
#  Text(16, 0, 'Carrick'),
#  Text(17, 0, 'Squirrel Hill South')]
